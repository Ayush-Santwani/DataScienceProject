# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\lenovo\Downloads\CarDataSet.csv")

# %%
df
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                             Maruti Wagon R LXI CNG
# 1              1                   Hyundai Creta 1.6 CRDi SX Option
# 2              2                                       Honda Jazz V
# 3              3                                  Maruti Ertiga VDI
# 4              4                    Audi A4 New 2.0 TDI Multitronic
# ...          ...                                                ...
# 7248        1229                  Volkswagen Vento Diesel Trendline
# 7249        1230                             Volkswagen Polo GT TSI
# 7250        1231                             Nissan Micra Diesel XV
# 7251        1232                             Volkswagen Polo GT TSI
# 7252        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         Mumbai  2010              72000       CNG       Manual      First
# 1           Pune  2015              41000    Diesel       Manual      First
# 2        Chennai  2011              46000    Petrol       Manual      First
# 3        Chennai  2012              87000    Diesel       Manual      First
# 4     Coimbatore  2013              40670    Diesel    Automatic     Second
# ...          ...   ...                ...       ...          ...        ...
# 7248   Hyderabad  2011              89411    Diesel       Manual      First
# 7249      Mumbai  2015              59000    Petrol    Automatic      First
# 7250     Kolkata  2012              28000    Diesel       Manual      First
# 7251        Pune  2013              52262    Petrol    Automatic      Third
# 7252       Kochi  2014              72443    Diesel    Automatic      First
#
#          Mileage   Engine      Power  Seats  New_Price  Price
# 0     26.6 km/kg   998 CC  58.16 bhp    5.0        NaN   1.75
# 1     19.67 kmpl  1582 CC  126.2 bhp    5.0        NaN  12.50
# 2      18.2 kmpl  1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 3     20.77 kmpl  1248 CC  88.76 bhp    7.0        NaN   6.00
# 4      15.2 kmpl  1968 CC  140.8 bhp    5.0        NaN  17.74
# ...          ...      ...        ...    ...        ...    ...
# 7248  20.54 kmpl  1598 CC  103.6 bhp    5.0        NaN    NaN
# 7249  17.21 kmpl  1197 CC  103.6 bhp    5.0        NaN    NaN
# 7250  23.08 kmpl  1461 CC   63.1 bhp    5.0        NaN    NaN
# 7251   17.2 kmpl  1197 CC  103.6 bhp    5.0        NaN    NaN
# 7252   10.0 kmpl  2148 CC    170 bhp    5.0        NaN    NaN
#
# [7253 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 823 entries, 2 to 6014
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         823 non-null    int64
#  1   Name               823 non-null    object
#  2   Location           823 non-null    object
#  3   Year               823 non-null    int64
#  4   Kilometers_Driven  823 non-null    int64
#  5   Fuel_Type          823 non-null    object
#  6   Transmission       823 non-null    object
#  7   Owner_Type         823 non-null    object
#  8   Mileage            823 non-null    object
#  9   Engine             823 non-null    object
#  10  Power              823 non-null    object
#  11  Seats              823 non-null    float64
#  12  New_Price          823 non-null    object
#  13  Price              823 non-null    float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 96.4+ KB

# %%
df.dropna(inplace=True,axis=0)
df
# Out:
#                                    Name Location  Year  Kilometers_Driven  \
# 2                          Honda Jazz V  Chennai  2011              46000
# 7     Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 10                     Maruti Ciaz Zeta    Kochi  2018              25692
# 15          Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 20                    BMW 3 Series 320d    Kochi  2014              32982
# ...                                 ...      ...   ...                ...
# 5999              Tata Bolt Revotron XT  Chennai  2016              10000
# 6002      Volkswagen Vento 1.6 Highline   Mumbai  2011              38000
# 6005           Maruti Vitara Brezza VDi     Pune  2016              37208
# 6010               Honda Brio 1.2 VX MT    Delhi  2013              33746
# 6014                   Maruti Swift VDI    Delhi  2014              27365
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  \
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC    88.7 bhp
# 7       Diesel    Automatic      First  11.36 kmpl  2755 CC   171.5 bhp
# 10      Petrol       Manual      First  21.56 kmpl  1462 CC  103.25 bhp
# 15      Diesel       Manual      First   13.5 kmpl  2477 CC  175.56 bhp
# 20      Diesel    Automatic      First  22.69 kmpl  1995 CC     190 bhp
# ...        ...          ...        ...         ...      ...         ...
# 5999    Petrol       Manual      First  17.57 kmpl  1193 CC    88.7 bhp
# 6002    Petrol       Manual      First  16.09 kmpl  1598 CC   103.5 bhp
# 6005    Diesel       Manual      First   24.3 kmpl  1248 CC    88.5 bhp
# 6010    Petrol       Manual      First   18.5 kmpl  1198 CC    86.8 bhp
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC      74 bhp
#
#       Seats  Price
# 2       5.0   4.50
# 7       8.0  17.50
# 10      5.0   9.95
# 15      7.0  15.00
# 20      5.0  18.55
# ...     ...    ...
# 5999    5.0   4.00
# 6002    5.0   3.25
# 6005    5.0   7.43
# 6010    5.0   3.20
# 6014    5.0   4.75
#
# [823 rows x 12 columns]

# %%
kmkg = 0
kmpl = 0
for i in df.Mileage:
    if str(i).endswith("km/kg"):
        kmkg+=1
    elif str(i).endswith("kmpl"):
        kmpl+=1
print('The number of rows with Km/Kg : {} '.format(kmkg))
print('The number of rows with Kmpl : {} '.format(kmpl))
# Out:
# The number of rows with Km/Kg : 9
# The number of rows with Kmpl : 814

# %%
df= df[df['Mileage']!= 'nan']
df
# Out:
#                                    Name Location  Year  Kilometers_Driven  \
# 2                          Honda Jazz V  Chennai  2011              46000
# 7     Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 10                     Maruti Ciaz Zeta    Kochi  2018              25692
# 15          Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 20                    BMW 3 Series 320d    Kochi  2014              32982
# ...                                 ...      ...   ...                ...
# 5999              Tata Bolt Revotron XT  Chennai  2016              10000
# 6002      Volkswagen Vento 1.6 Highline   Mumbai  2011              38000
# 6005           Maruti Vitara Brezza VDi     Pune  2016              37208
# 6010               Honda Brio 1.2 VX MT    Delhi  2013              33746
# 6014                   Maruti Swift VDI    Delhi  2014              27365
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  \
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC    88.7 bhp
# 7       Diesel    Automatic      First  11.36 kmpl  2755 CC   171.5 bhp
# 10      Petrol       Manual      First  21.56 kmpl  1462 CC  103.25 bhp
# 15      Diesel       Manual      First   13.5 kmpl  2477 CC  175.56 bhp
# 20      Diesel    Automatic      First  22.69 kmpl  1995 CC     190 bhp
# ...        ...          ...        ...         ...      ...         ...
# 5999    Petrol       Manual      First  17.57 kmpl  1193 CC    88.7 bhp
# 6002    Petrol       Manual      First  16.09 kmpl  1598 CC   103.5 bhp
# 6005    Diesel       Manual      First   24.3 kmpl  1248 CC    88.5 bhp
# 6010    Petrol       Manual      First   18.5 kmpl  1198 CC    86.8 bhp
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC      74 bhp
#
#       Seats  Price
# 2       5.0   4.50
# 7       8.0  17.50
# 10      5.0   9.95
# 15      7.0  15.00
# 20      5.0  18.55
# ...     ...    ...
# 5999    5.0   4.00
# 6002    5.0   3.25
# 6005    5.0   7.43
# 6010    5.0   3.20
# 6014    5.0   4.75
#
# [823 rows x 12 columns]

# %%
Correct_Mileage= []
for i in df.Mileage:
    if str(i).endswith('km/kg'):
        i = i[:-6]
        i = float(i)*1.40
        Correct_Mileage.append(float(i))
    elif str(i).endswith('kmpl'):
        i = i[:-6]
        #print(i)
        Correct_Mileage.append(float(i))

# %%
plt.scatter(df['Year'],df['Kilometers_Driven'])
plt.show()

# %%
df = df[df['Kilometers_Driven']<6000000]
df
# Out:
#                                    Name Location  Year  Kilometers_Driven  \
# 2                          Honda Jazz V  Chennai  2011              46000
# 7     Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 10                     Maruti Ciaz Zeta    Kochi  2018              25692
# 15          Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 20                    BMW 3 Series 320d    Kochi  2014              32982
# ...                                 ...      ...   ...                ...
# 5999              Tata Bolt Revotron XT  Chennai  2016              10000
# 6002      Volkswagen Vento 1.6 Highline   Mumbai  2011              38000
# 6005           Maruti Vitara Brezza VDi     Pune  2016              37208
# 6010               Honda Brio 1.2 VX MT    Delhi  2013              33746
# 6014                   Maruti Swift VDI    Delhi  2014              27365
#
#      Fuel_Type Transmission Owner_Type  Mileage   Engine       Power  Seats  \
# 2       Petrol       Manual      First     18.0  1199 CC    88.7 bhp    5.0
# 7       Diesel    Automatic      First     11.3  2755 CC   171.5 bhp    8.0
# 10      Petrol       Manual      First     21.5  1462 CC  103.25 bhp    5.0
# 15      Diesel       Manual      First     13.0  2477 CC  175.56 bhp    7.0
# 20      Diesel    Automatic      First     22.6  1995 CC     190 bhp    5.0
# ...        ...          ...        ...      ...      ...         ...    ...
# 5999    Petrol       Manual      First     17.5  1193 CC    88.7 bhp    5.0
# 6002    Petrol       Manual      First     16.0  1598 CC   103.5 bhp    5.0
# 6005    Diesel       Manual      First     24.0  1248 CC    88.5 bhp    5.0
# 6010    Petrol       Manual      First     18.0  1198 CC    86.8 bhp    5.0
# 6014    Diesel       Manual      First     28.0  1248 CC      74 bhp    5.0
#
#       Price
# 2      4.50
# 7     17.50
# 10     9.95
# 15    15.00
# 20    18.55
# ...     ...
# 5999   4.00
# 6002   3.25
# 6005   7.43
# 6010   3.20
# 6014   4.75
#
# [823 rows x 12 columns]

# %%
fig,ax=plt.subplots(1,3,figsize=(20,5))
ax[0].scatter(df['Mileage'],df['Price'])
ax[1].scatter(df['Fuel_Type'],df['Price'])
ax[2].scatter(df['Transmission'],df['Price'])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
X_train,X_test,Y_train,Y_test=train_test_split(df[['Mileage']],df[['Price']],test_size=0.3,random_state=12)

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(X_test)
pred
# Out:
# array([[ 15.33007357],
#        [ 17.79911089],
#        [ 20.50329462],
#        [ 10.62714534],
#        [ 16.50580563],
#        [ 10.62714534],
#        [ 11.68530419],
#        [  4.74848505],
#        [ 14.15434151],
#        [ 20.0330018 ],
#        [ 12.27317022],
#        [ 14.15434151],
#        [ 23.56019798],
#        [  3.57275299],
#        [ 14.15434151],
#        [ 15.9179396 ],
#        [ 20.50329462],
#        [ 23.20747836],
#        [ 16.50580563],
#        [ 15.33007357],
#        [ 20.0330018 ],
#        [ 11.8028774 ],
#        [ 14.15434151],
#        [ 14.74220754],
#        [ 22.97233195],
#        [ 15.33007357],
#        [  8.27568122],
#        [ 16.50580563],
#        [ 22.97233195],
#        [  8.86354725],
#        [ 22.97233195],
#        [ 10.62714534],
#        [ 10.97986496],
#        [  9.8041329 ],
#        [ 11.09743816],
#        [ 10.62714534],
#        [ 11.8028774 ],
#        [ 16.27065922],
#        [ 23.20747836],
#        [ 15.33007357],
#        [ 10.15685252],
#        [ 15.33007357],
#        [ 17.68153769],
#        [ 19.79785539],
#        [ 21.20873386],
#        [  8.27568122],
#        [  4.74848505],
#        [ 20.50329462],
#        [ 20.50329462],
#        [ 20.50329462],
#        [ 12.86103625],
#        [ 21.67902668],
#        [ 13.21375587],
#        [ 16.50580563],
#        [ 15.56521998],
#        [ 12.27317022],
#        [ 15.09492716],
#        [ 12.97860945],
#        [  3.57275299],
#        [  6.62965634],
#        [ 12.86103625],
#        [ 10.62714534],
#        [  8.27568122],
#        [ 11.8028774 ],
#        [ 23.20747836],
#        [  9.9217061 ],
#        [  7.09994917],
#        [ 36.49325061],
#        [ 16.50580563],
#        [ 15.09492716],
#        [ 10.62714534],
#        [-16.60751205],
#        [ 18.73969654],
#        [  7.09994917],
#        [ 11.8028774 ],
#        [ 18.85726974],
#        [ 10.62714534],
#        [ 12.27317022],
#        [ 19.79785539],
#        [ 20.50329462],
#        [  8.27568122],
#        [ 13.8016219 ],
#        [ 15.33007357],
#        [  8.51082763],
#        [  8.27568122],
#        [ 16.50580563],
#        [  7.09994917],
#        [ 17.68153769],
#        [ 18.85726974],
#        [ 36.49325061],
#        [  3.57275299],
#        [ 11.8028774 ],
#        [ 11.21501137],
#        [ 23.56019798],
#        [ 21.20873386],
#        [  8.51082763],
#        [  8.27568122],
#        [ 12.27317022],
#        [ 20.50329462],
#        [ 23.20747836],
#        [ 16.50580563],
#        [ 17.79911089],
#        [ 18.97484295],
#        [  8.51082763],
#        [ 10.62714534],
#        [ 23.20747836],
#        [  9.9217061 ],
#        [  3.57275299],
#        [ 11.8028774 ],
#        [ 16.50580563],
#        [ 16.50580563],
#        [ 15.9179396 ],
#        [ 19.79785539],
#        [  3.57275299],
#        [ 23.20747836],
#        [ 15.33007357],
#        [ 15.33007357],
#        [ 10.62714534],
#        [ 16.50580563],
#        [  8.51082763],
#        [ 10.15685252],
#        [ 10.97986496],
#        [ 14.15434151],
#        [  9.9217061 ],
#        [ 15.33007357],
#        [ 16.50580563],
#        [  7.09994917],
#        [  8.27568122],
#        [ 18.62212333],
#        [ 10.62714534],
#        [ 19.79785539],
#        [ 11.33258457],
#        [ 10.62714534],
#        [ 16.50580563],
#        [ 11.8028774 ],
#        [ 23.20747836],
#        [  7.09994917],
#        [  6.98237596],
#        [ 18.85726974],
#        [ 15.33007357],
#        [  8.27568122],
#        [ 14.15434151],
#        [ 19.32756257],
#        [ 10.15685252],
#        [ 14.74220754],
#        [ 16.03551281],
#        [ 19.32756257],
#        [ 15.33007357],
#        [  6.62965634],
#        [ 11.8028774 ],
#        [ 15.9179396 ],
#        [  9.9217061 ],
#        [ 19.20998936],
#        [ 10.62714534],
#        [  8.27568122],
#        [ 11.8028774 ],
#        [  8.27568122],
#        [ 17.68153769],
#        [ 16.50580563],
#        [  9.56898649],
#        [  3.57275299],
#        [ 13.44890228],
#        [ 15.33007357],
#        [ 20.85601424],
#        [ 16.74095204],
#        [ 22.97233195],
#        [ 19.32756257],
#        [ 22.38446592],
#        [ 19.32756257],
#        [ 13.33132907],
#        [ 18.85726974],
#        [ 11.8028774 ],
#        [  3.57275299],
#        [ 12.97860945],
#        [ 15.33007357],
#        [  7.09994917],
#        [ 16.62337883],
#        [ 10.62714534],
#        [ 13.21375587],
#        [ 14.50706113],
#        [ 21.20873386],
#        [ 20.50329462],
#        [  9.45141328],
#        [ 16.50580563],
#        [ 10.62714534],
#        [ 10.97986496],
#        [ 14.74220754],
#        [  8.27568122],
#        [ 23.20747836],
#        [  9.45141328],
#        [ 18.38697692],
#        [ 11.8028774 ],
#        [  8.27568122],
#        [ 14.03676831],
#        [-15.83388035],
#        [ 14.74220754],
#        [ 18.97484295],
#        [  8.27568122],
#        [ 15.21250036],
#        [ 12.27317022],
#        [ 16.50580563],
#        [ 21.20873386],
#        [ 12.97860945],
#        [  8.27568122],
#        [ 19.79785539],
#        [  9.45141328],
#        [ 21.20873386],
#        [ 10.97986496],
#        [ 11.21501137],
#        [ 14.74220754],
#        [  5.92421711],
#        [ 23.20747836],
#        [ 16.74095204],
#        [ 16.27065922],
#        [ 10.62714534],
#        [ 17.79911089],
#        [ 21.20873386],
#        [ 10.62714534],
#        [ 18.85726974],
#        [ 10.62714534],
#        [ 21.20873386],
#        [ 16.50580563],
#        [ 20.50329462],
#        [  8.27568122],
#        [ 23.20747836],
#        [ 11.09743816],
#        [ 17.68153769],
#        [ 19.79785539],
#        [ 21.20873386],
#        [  8.27568122],
#        [  3.57275299],
#        [ 10.62714534],
#        [  8.51082763],
#        [ 10.15685252],
#        [ 22.38446592],
#        [ 23.32505156],
#        [ 15.21250036],
#        [ 12.86103625],
#        [ 16.50580563],
#        [ 21.20873386],
#        [ 14.03676831],
#        [ 15.33007357],
#        [ 10.15685252],
#        [ 20.50329462],
#        [ 21.67902668],
#        [ 16.50580563],
#        [ 15.9179396 ]])

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
r2_score(Y_test,pred)
# Out:
# 0.1805718088653112

# %%
np.sqrt(mean_squared_error(Y_test,pred))
# Out:
# 12.677092716969318

# %%
m=model.coef_

# %%
m
# Out:
# array([[-1.17573206]])

# %%
c=model.intercept_

# %%
c
# Out:
# array([36.49325061])

# %%
df.corr()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_11612\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                        Year  Kilometers_Driven   Mileage     Seats     Price
# Year               1.000000          -0.520334 -0.125312  0.074964  0.227202
# Kilometers_Driven -0.520334           1.000000  0.062150  0.212490 -0.154463
# Mileage           -0.125312           0.062150  1.000000 -0.360737 -0.404352
# Seats              0.074964           0.212490 -0.360737  1.000000  0.046168
# Price              0.227202          -0.154463 -0.404352  0.046168  1.000000

# %%
X_train1,X_test1,Y_train1,Y_test1=train_test_split(df[['Mileage']],df[['Price']],test_size=0.3,random_state=12)

# %%
pred
# Out:
# array([[ 15.33007357],
#        [ 17.79911089],
#        [ 20.50329462],
#        [ 10.62714534],
#        [ 16.50580563],
#        [ 10.62714534],
#        [ 11.68530419],
#        [  4.74848505],
#        [ 14.15434151],
#        [ 20.0330018 ],
#        [ 12.27317022],
#        [ 14.15434151],
#        [ 23.56019798],
#        [  3.57275299],
#        [ 14.15434151],
#        [ 15.9179396 ],
#        [ 20.50329462],
#        [ 23.20747836],
#        [ 16.50580563],
#        [ 15.33007357],
#        [ 20.0330018 ],
#        [ 11.8028774 ],
#        [ 14.15434151],
#        [ 14.74220754],
#        [ 22.97233195],
#        [ 15.33007357],
#        [  8.27568122],
#        [ 16.50580563],
#        [ 22.97233195],
#        [  8.86354725],
#        [ 22.97233195],
#        [ 10.62714534],
#        [ 10.97986496],
#        [  9.8041329 ],
#        [ 11.09743816],
#        [ 10.62714534],
#        [ 11.8028774 ],
#        [ 16.27065922],
#        [ 23.20747836],
#        [ 15.33007357],
#        [ 10.15685252],
#        [ 15.33007357],
#        [ 17.68153769],
#        [ 19.79785539],
#        [ 21.20873386],
#        [  8.27568122],
#        [  4.74848505],
#        [ 20.50329462],
#        [ 20.50329462],
#        [ 20.50329462],
#        [ 12.86103625],
#        [ 21.67902668],
#        [ 13.21375587],
#        [ 16.50580563],
#        [ 15.56521998],
#        [ 12.27317022],
#        [ 15.09492716],
#        [ 12.97860945],
#        [  3.57275299],
#        [  6.62965634],
#        [ 12.86103625],
#        [ 10.62714534],
#        [  8.27568122],
#        [ 11.8028774 ],
#        [ 23.20747836],
#        [  9.9217061 ],
#        [  7.09994917],
#        [ 36.49325061],
#        [ 16.50580563],
#        [ 15.09492716],
#        [ 10.62714534],
#        [-16.60751205],
#        [ 18.73969654],
#        [  7.09994917],
#        [ 11.8028774 ],
#        [ 18.85726974],
#        [ 10.62714534],
#        [ 12.27317022],
#        [ 19.79785539],
#        [ 20.50329462],
#        [  8.27568122],
#        [ 13.8016219 ],
#        [ 15.33007357],
#        [  8.51082763],
#        [  8.27568122],
#        [ 16.50580563],
#        [  7.09994917],
#        [ 17.68153769],
#        [ 18.85726974],
#        [ 36.49325061],
#        [  3.57275299],
#        [ 11.8028774 ],
#        [ 11.21501137],
#        [ 23.56019798],
#        [ 21.20873386],
#        [  8.51082763],
#        [  8.27568122],
#        [ 12.27317022],
#        [ 20.50329462],
#        [ 23.20747836],
#        [ 16.50580563],
#        [ 17.79911089],
#        [ 18.97484295],
#        [  8.51082763],
#        [ 10.62714534],
#        [ 23.20747836],
#        [  9.9217061 ],
#        [  3.57275299],
#        [ 11.8028774 ],
#        [ 16.50580563],
#        [ 16.50580563],
#        [ 15.9179396 ],
#        [ 19.79785539],
#        [  3.57275299],
#        [ 23.20747836],
#        [ 15.33007357],
#        [ 15.33007357],
#        [ 10.62714534],
#        [ 16.50580563],
#        [  8.51082763],
#        [ 10.15685252],
#        [ 10.97986496],
#        [ 14.15434151],
#        [  9.9217061 ],
#        [ 15.33007357],
#        [ 16.50580563],
#        [  7.09994917],
#        [  8.27568122],
#        [ 18.62212333],
#        [ 10.62714534],
#        [ 19.79785539],
#        [ 11.33258457],
#        [ 10.62714534],
#        [ 16.50580563],
#        [ 11.8028774 ],
#        [ 23.20747836],
#        [  7.09994917],
#        [  6.98237596],
#        [ 18.85726974],
#        [ 15.33007357],
#        [  8.27568122],
#        [ 14.15434151],
#        [ 19.32756257],
#        [ 10.15685252],
#        [ 14.74220754],
#        [ 16.03551281],
#        [ 19.32756257],
#        [ 15.33007357],
#        [  6.62965634],
#        [ 11.8028774 ],
#        [ 15.9179396 ],
#        [  9.9217061 ],
#        [ 19.20998936],
#        [ 10.62714534],
#        [  8.27568122],
#        [ 11.8028774 ],
#        [  8.27568122],
#        [ 17.68153769],
#        [ 16.50580563],
#        [  9.56898649],
#        [  3.57275299],
#        [ 13.44890228],
#        [ 15.33007357],
#        [ 20.85601424],
#        [ 16.74095204],
#        [ 22.97233195],
#        [ 19.32756257],
#        [ 22.38446592],
#        [ 19.32756257],
#        [ 13.33132907],
#        [ 18.85726974],
#        [ 11.8028774 ],
#        [  3.57275299],
#        [ 12.97860945],
#        [ 15.33007357],
#        [  7.09994917],
#        [ 16.62337883],
#        [ 10.62714534],
#        [ 13.21375587],
#        [ 14.50706113],
#        [ 21.20873386],
#        [ 20.50329462],
#        [  9.45141328],
#        [ 16.50580563],
#        [ 10.62714534],
#        [ 10.97986496],
#        [ 14.74220754],
#        [  8.27568122],
#        [ 23.20747836],
#        [  9.45141328],
#        [ 18.38697692],
#        [ 11.8028774 ],
#        [  8.27568122],
#        [ 14.03676831],
#        [-15.83388035],
#        [ 14.74220754],
#        [ 18.97484295],
#        [  8.27568122],
#        [ 15.21250036],
#        [ 12.27317022],
#        [ 16.50580563],
#        [ 21.20873386],
#        [ 12.97860945],
#        [  8.27568122],
#        [ 19.79785539],
#        [  9.45141328],
#        [ 21.20873386],
#        [ 10.97986496],
#        [ 11.21501137],
#        [ 14.74220754],
#        [  5.92421711],
#        [ 23.20747836],
#        [ 16.74095204],
#        [ 16.27065922],
#        [ 10.62714534],
#        [ 17.79911089],
#        [ 21.20873386],
#        [ 10.62714534],
#        [ 18.85726974],
#        [ 10.62714534],
#        [ 21.20873386],
#        [ 16.50580563],
#        [ 20.50329462],
#        [  8.27568122],
#        [ 23.20747836],
#        [ 11.09743816],
#        [ 17.68153769],
#        [ 19.79785539],
#        [ 21.20873386],
#        [  8.27568122],
#        [  3.57275299],
#        [ 10.62714534],
#        [  8.51082763],
#        [ 10.15685252],
#        [ 22.38446592],
#        [ 23.32505156],
#        [ 15.21250036],
#        [ 12.86103625],
#        [ 16.50580563],
#        [ 21.20873386],
#        [ 14.03676831],
#        [ 15.33007357],
#        [ 10.15685252],
#        [ 20.50329462],
#        [ 21.67902668],
#        [ 16.50580563],
#        [ 15.9179396 ]])

# %%
result2=pd.DataFrame()
result2['Mileage']=X_test['Mileage']
result2['Actual']=Y_test['Price']
result2['predicted']=pred
result2.head()
# Out:
#       Mileage  Actual  predicted
# 6010     18.0    3.20  15.330074
# 1589     15.9    5.50  17.799111
# 952      13.6   18.39  20.503295
# 5479     22.0    4.50  10.627145
# 5049     17.0   15.00  16.505806

# %%
result2['error']=abs(result2['Actual']-result2['predicted'])

# %%
result2['error %']=result2['error']/result2['Actual']*100

# %%
result2
# Out:
#       Mileage  Actual  predicted      error     error %
# 6010     18.0    3.20  15.330074  12.130074  379.064799
# 1589     15.9    5.50  17.799111  12.299111  223.620198
# 952      13.6   18.39  20.503295   2.113295   11.491542
# 5479     22.0    4.50  10.627145   6.127145  136.158785
# 5049     17.0   15.00  16.505806   1.505806   10.038704
# ...       ...     ...        ...        ...         ...
# 4551     22.4   17.27  10.156853   7.113147   41.187884
# 850      13.6   18.60  20.503295   1.903295   10.232767
# 3163     12.6   27.36  21.679027   5.680973   20.763791
# 237      17.0    3.87  16.505806  12.635806  326.506605
# 3168     17.5    4.65  15.917940  11.267940  242.321282
#
# [247 rows x 5 columns]
